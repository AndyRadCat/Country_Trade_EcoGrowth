# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import statsmodels.api as sm
import xlrd

# %matplotlib inline
sns.set_palette("pastel")

# %%
pta = pd.read_excel('pta-agreements_1.xls')

# %%
pta
# Out:
#          Unnamed: 0                                         Unnamed: 1  \
# 0         Worksheet                                           Contents
# 1            WTO+AC  Provisions falling under the current mandate o...
# 2               NaN                                                NaN
# 3            WTO+LE  Provisions falling under the current mandate o...
# 4               NaN                                                NaN
# ..              ...                                                ...
# 70   Social Matters  Coordination of social security systems; non-d...
# 71       Statistics  Harmonisation and/or development of statistica...
# 72         Taxation     Assistance in conducting fiscal system reforms
# 73        Terrorism  Exchange of information and experience; joint ...
# 74  Visa and Asylum  Exchange of information; drafting legislation;...
#
#                                            Unnamed: 2
# 0   Description of variables concerning PTA's prov...
# ...
